# %% [markdown]
# # <font color = green>**CNN Skin Cancer detection assignment**<font>
#
# ## <font color = blue> **Problem statement:** <font>
# To build a CNN based model which can accurately detect **melanoma**. Melanoma is a type of cancer that can be deadly if not detected early. It accounts for ***75% of skin cancer deaths***. A solution which can evaluate images and alert the dermatologists about the presence of melanoma has the potential to reduce a lot of manual effort needed in diagnosis.
#
# ## <font color = red> **Business Goal** <font>
#
# To build a CNN based model which can accurately detect melanoma

# %%
# Importing all necessary python library 
import pathlib
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import PIL
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %% [markdown]
# Importing Necessary Data from my *Google Drive*, can you get the data fom [here](https://drive.google.com/file/d/1xLfSQUGDl8ezNNbUkpuHOYvSpTyxVhCs/view?usp=sharing)
#
# The data set contains the following **diseases**:
#
# *   Actinic keratosis
# *   Basal cell carcinoma
# *   Dermatofibroma
# *   Melanoma
# *   Nevus
# *   Pigmented benign keratosis
# *   Seborrheic keratosis
# *   Squamous cell carcinoma
# *   Vascular lesion

# %%
# Defining the path for train and test images
data_dir_train = pathlib.Path("/content/drive/MyDrive/Upgrad/ML2/CNN Project/Melanoma-Detection-Assignment/Train")
data_dir_test = pathlib.Path("/content/drive/MyDrive/Upgrad/ML2/CNN Project/Melanoma-Detection-Assignment/Test")

# %%
# Getting the image count of Test and Train 
image_count_train = len(list(data_dir_train.glob('*/*.jpg')))
print(image_count_train)
image_count_test = len(list(data_dir_test.glob('*/*.jpg')))
print(image_count_test)
# Out:
# 2239
# 118

# %% [markdown]
# **Load using keras.preprocessing**
#
# Let's load these images off disk using the helpful image_dataset_from_directory utility.

# %% [markdown]
# ## Step 1: Create a dataset
# Define some parameters for the loader:

# %%
# Create a dataset
# Define some parameters for the loader:

batch_size = 32
img_height = 180
img_width = 180

# %%
# Let's visualize one image first, to verify it is working or not.
basal_cell_carcinoma = list(data_dir_train.glob('basal cell carcinoma/*'))
PIL.Image.open(str(basal_cell_carcinoma[1]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x450 at 0x7FD571C0FF70>

# %% [markdown]
# Use 80% of the images for training, and 20% for validation.

# %%
## Write your train dataset here
## Note use seed=123 while creating your dataset using tf.keras.preprocessing.image_dataset_from_directory
## Note, make sure your resize your images to the size img_height*img_width, while writting the datase


train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir_train,
    seed=123,
    validation_split = 0.2,
    subset='training',
    image_size=(img_height, img_width),  
    batch_size=batch_size)
# Out:
# Found 6739 files belonging to 9 classes.
# Using 5392 files for training.

# %%
## Write your validation dataset here
## Note use seed=123 while creating your dataset using tf.keras.preprocessing.image_dataset_from_directory
## Note, make sure your resize your images to the size img_height*img_width, while writting the dataset
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir_train,
    seed=123,
    validation_split = 0.2,
    subset='validation',
    image_size=(img_height, img_width),  
    batch_size=batch_size)
# Out:
# Found 6739 files belonging to 9 classes.
# Using 1347 files for validation.

# %%
# List out all the classes of skin cancer and store them in a list. 
# You can find the class names in the class_names attribute on these datasets. 
# These correspond to the directory names in alphabetical order.
class_names = train_ds.class_names
print(class_names)
# Out:
# ['actinic keratosis', 'basal cell carcinoma', 'dermatofibroma', 'melanoma', 'nevus', 'pigmented benign keratosis', 'seborrheic keratosis', 'squamous cell carcinoma', 'vascular lesion']

# %% [markdown]
# ## **Step 2:  Visualize the data**
#
# *Todo, create a code to visualize one instance of all the nine classes present in the dataset*

# %%
import matplotlib.pyplot as plt

### your code goes here, you can use training or validation data to visualize

plt.figure(figsize=(12, 12))
for images, labels in train_ds.take(1):
  for i in range(12):
    ax = plt.subplot(4, 4, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %%
for image_batch, labels_batch in train_ds:
  print("image_batch: ", image_batch.shape)
  print("labels_batch: ", labels_batch.shape)
  break
# Out:
# image_batch:  (32, 180, 180, 3)
# labels_batch:  (32,)

# %% [markdown]
# The image_batch is a tensor of the shape *(32, 180, 180, 3)*. This is a batch of 32 images of shape 180x180x3 (the last dimension refers to color channels RGB). The label_batch is a tensor of the shape (32,), these are corresponding labels to the 32 images.
#
# `Dataset.cache()` keeps the images in memory after they're loaded off disk during the first epoch.
#
# `Dataset.prefetch()` overlaps data preprocessing and model execution while training.

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# ## Step 3: Create the model
# Todo: Create a CNN model, which can accurately detect 9 classes present in the dataset. Use `layers.experimental.preprocessing.Rescaling` to normalize pixel values between (0,1). The RGB channel values are in the [0, 255] range. This is not ideal for a neural network. Here, it is good to standardize values to be in the [0, 1]

# %%
num_classes = 9 # As target class has 9 labels

model = Sequential([
  layers.experimental.preprocessing.Rescaling(1./255, input_shape=(img_height, img_width, 3)),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])

# %% [markdown]
# **Compile the model**
# Choose an appropirate optimiser and loss function for model training

# %%
### Todo, choose an appropirate optimiser and loss function
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
# View the summary of all layers
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 180, 180, 3)       0
#
#  conv2d (Conv2D)             (None, 180, 180, 16)      448
#
#  max_pooling2d (MaxPooling2D  (None, 90, 90, 16)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 90, 90, 32)        4640
#
#  max_pooling2d_1 (MaxPooling  (None, 45, 45, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 45, 45, 64)        18496
#
#  max_pooling2d_2 (MaxPooling  (None, 22, 22, 64)       0
#  2D)
#
#  flatten (Flatten)           (None, 30976)             0
#
#  dense (Dense)               (None, 128)               3965056
#
#  dense_1 (Dense)             (None, 9)                 1161
#
# =================================================================
# Total params: 3,989,801
# Trainable params: 3,989,801
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Step 4: Train the model

# %%
epochs = 20
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/20
# 169/169 [==============================] - 1198s 2s/step - loss: 1.7296 - accuracy: 0.3355 - val_loss: 1.4838 - val_accuracy: 0.4232
# Epoch 2/20
# 169/169 [==============================] - 200s 1s/step - loss: 1.3509 - accuracy: 0.4937 - val_loss: 1.2626 - val_accuracy: 0.5189
# Epoch 3/20
# 169/169 [==============================] - 181s 1s/step - loss: 1.1176 - accuracy: 0.5827 - val_loss: 1.1179 - val_accuracy: 0.5687
# Epoch 4/20
# 169/169 [==============================] - 174s 1s/step - loss: 0.9229 - accuracy: 0.6647 - val_loss: 0.8862 - val_accuracy: 0.6845
# Epoch 5/20
# 169/169 [==============================] - 173s 1s/step - loss: 0.7197 - accuracy: 0.7398 - val_loss: 0.8943 - val_accuracy: 0.6652
# Epoch 6/20
# 169/169 [==============================] - 182s 1s/step - loss: 0.5806 - accuracy: 0.7921 - val_loss: 0.7906 - val_accuracy: 0.7350
# Epoch 7/20
# 169/169 [==============================] - 176s 1s/step - loss: 0.5163 - accuracy: 0.8192 - val_loss: 0.9300 - val_accuracy: 0.7030
# Epoch 8/20
# 169/169 [==============================] - 180s 1s/step - loss: 0.4331 - accuracy: 0.8479 - val_loss: 0.7647 - val_accuracy: 0.7550
# Epoch 9/20
# 169/169 [==============================] - 181s 1s/step - loss: 0.3378 - accuracy: 0.8757 - val_loss: 0.6849 - val_accuracy: 0.8055
# Epoch 10/20
# 169/169 [==============================] - 191s 1s/step - loss: 0.2764 - accuracy: 0.8989 - val_loss: 0.7070 - val_accuracy: 0.8070
# Epoch 11/20
# 169/169 [==============================] - 190s 1s/step - loss: 0.2335 - accuracy: 0.9123 - val_loss: 0.6948 - val_accuracy: 0.8137
# Epoch 12/20
# 169/169 [==============================] - 198s 1s/step - loss: 0.2421 - accuracy: 0.9121 - val_loss: 0.8035 - val_accuracy: 0.7958
# Epoch 13/20
# 169/169 [==============================] - 201s 1s/step - loss: 0.2029 - accuracy: 0.9201 - val_loss: 0.7178 - val_accuracy: 0.8196
# Epoch 14/20
# 169/169 [==============================] - 189s 1s/step - loss: 0.2193 - accuracy: 0.9266 - val_loss: 0.7670 - val_accuracy: 0.8070
# Epoch 15/20
# 169/169 [==============================] - 191s 1s/step - loss: 0.1596 - accuracy: 0.9410 - val_loss: 0.7128 - val_accuracy: 0.7892
# Epoch 16/20
# 169/169 [==============================] - 194s 1s/step - loss: 0.1446 - accuracy: 0.9418 - val_loss: 0.9186 - val_accuracy: 0.7706
# Epoch 17/20
# 169/169 [==============================] - 188s 1s/step - loss: 0.1470 - accuracy: 0.9395 - val_loss: 0.7728 - val_accuracy: 0.8085
# Epoch 18/20
# 169/169 [==============================] - 182s 1s/step - loss: 0.1586 - accuracy: 0.9388 - val_loss: 0.7118 - val_accuracy: 0.8367
# Epoch 19/20
# 169/169 [==============================] - 189s 1s/step - loss: 0.1314 - accuracy: 0.9477 - val_loss: 0.7261 - val_accuracy: 0.8040
# Epoch 20/20
# 169/169 [==============================] - 183s 1s/step - loss: 0.1607 - accuracy: 0.9349 - val_loss: 0.7789 - val_accuracy: 0.8307

# %% [markdown]
# ## Step 5: Visualizing training results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

fig = plt.figure(figsize=(10, 10))
fig.patch.set_facecolor('xkcd:mint green')

plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# **Todo: Write your findings after the model fit, see if there is an evidence of model overfit or underfit**
#
# **Write your findings here**
#
# **Comment:**
#
# 1.   Training accuracy of the model seems to increase
# linearly whereas validation accuracy remained stagnant around 55%
# 2.   High training accuracy means the model has learnt the noise in the data as well, however its poor performance on validation data shows lack of generalisability of the model.
# 3.   The above observations confirm the case of overfitting. To mitigate overfitting augmentation technique will be used. Since the training data available is less, we will generate new samples by slightly modifying the existing training data (for eg. flipping the image horizontally/vertically, slightly rotating the image etc) and use them for training the model as well.
#
# *There are multiple ways to fight overfitting in the training process.*
#
# *   **Data augmentation:**
# *   **Dropouts:**

# %%
# Todo, after you have analysed the model fit history for presence of underfit or overfit, choose an appropriate data augumentation strategy. 

data_augmentation = keras.Sequential([
                                      layers.experimental.preprocessing.RandomFlip("horizontal", input_shape=(img_height, img_width, 3)),
                                      layers.experimental.preprocessing.RandomRotation(0.1),
                                      layers.experimental.preprocessing.RandomZoom(0.1),
])

# %%
# Todo, visualize how your augmentation strategy works for one instance of training image.
plt.figure(figsize=(12, 12))
for images, labels in train_ds.take(1):
  for i in range(12):
    augmented_images = data_augmentation(images)
    ax = plt.subplot(4, 4, i + 1)
    plt.imshow(augmented_images[0].numpy().astype("uint8"))
    plt.axis("off")

# %% [markdown]
# **Todo:**
#
# **Create the model, compile and train the model**

# %%
## You can use Dropout layer if there is an evidence of overfitting in your findings

model = Sequential([
  data_augmentation,
  layers.experimental.preprocessing.Rescaling(1./255),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Dropout(0.2),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])

# %% [markdown]
# ## Step 6: Compiling the model

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %% [markdown]
# ## Step 7: Training the model

# %%
## Your code goes here, note: train your model for 20 epochs
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/20
# 169/169 [==============================] - 206s 1s/step - loss: 1.8002 - accuracy: 0.3030 - val_loss: 1.6031 - val_accuracy: 0.4091
# Epoch 2/20
# 169/169 [==============================] - 199s 1s/step - loss: 1.4805 - accuracy: 0.4377 - val_loss: 1.5156 - val_accuracy: 0.4128
# Epoch 3/20
# 169/169 [==============================] - 200s 1s/step - loss: 1.3734 - accuracy: 0.4679 - val_loss: 1.2931 - val_accuracy: 0.5093
# Epoch 4/20
# 169/169 [==============================] - 198s 1s/step - loss: 1.3029 - accuracy: 0.5032 - val_loss: 1.2014 - val_accuracy: 0.5338
# Epoch 5/20
# 169/169 [==============================] - 211s 1s/step - loss: 1.2148 - accuracy: 0.5267 - val_loss: 1.3864 - val_accuracy: 0.4915
# Epoch 6/20
# 169/169 [==============================] - 250s 1s/step - loss: 1.1971 - accuracy: 0.5419 - val_loss: 1.2454 - val_accuracy: 0.5226
# Epoch 7/20
# 169/169 [==============================] - 218s 1s/step - loss: 1.1389 - accuracy: 0.5564 - val_loss: 1.3048 - val_accuracy: 0.5093
# Epoch 8/20
# 169/169 [==============================] - 210s 1s/step - loss: 1.1365 - accuracy: 0.5640 - val_loss: 1.0804 - val_accuracy: 0.5754
# Epoch 9/20
# 169/169 [==============================] - 214s 1s/step - loss: 1.0095 - accuracy: 0.6155 - val_loss: 1.0361 - val_accuracy: 0.6095
# Epoch 10/20
# 169/169 [==============================] - 216s 1s/step - loss: 0.9997 - accuracy: 0.6133 - val_loss: 1.1261 - val_accuracy: 0.5679
# Epoch 11/20
# 169/169 [==============================] - 216s 1s/step - loss: 0.9598 - accuracy: 0.6361 - val_loss: 1.0042 - val_accuracy: 0.6221
# Epoch 12/20
# 169/169 [==============================] - 213s 1s/step - loss: 0.9011 - accuracy: 0.6665 - val_loss: 0.9148 - val_accuracy: 0.6459
# Epoch 13/20
# 169/169 [==============================] - 212s 1s/step - loss: 0.8711 - accuracy: 0.6628 - val_loss: 0.8600 - val_accuracy: 0.6830
# Epoch 14/20
# 169/169 [==============================] - 207s 1s/step - loss: 0.8287 - accuracy: 0.6849 - val_loss: 0.8023 - val_accuracy: 0.6837
# Epoch 15/20
# 169/169 [==============================] - 211s 1s/step - loss: 0.7947 - accuracy: 0.7051 - val_loss: 0.8284 - val_accuracy: 0.6949
# Epoch 16/20
# 169/169 [==============================] - 210s 1s/step - loss: 0.7885 - accuracy: 0.6975 - val_loss: 0.8415 - val_accuracy: 0.6897
# Epoch 17/20
# 169/169 [==============================] - 209s 1s/step - loss: 0.7292 - accuracy: 0.7235 - val_loss: 0.7390 - val_accuracy: 0.7327
# Epoch 18/20
# 169/169 [==============================] - 207s 1s/step - loss: 0.7377 - accuracy: 0.7218 - val_loss: 0.8670 - val_accuracy: 0.6815
# Epoch 19/20
# 169/169 [==============================] - 203s 1s/step - loss: 0.6705 - accuracy: 0.7528 - val_loss: 0.7519 - val_accuracy: 0.7290
# Epoch 20/20
# 169/169 [==============================] - 207s 1s/step - loss: 0.6332 - accuracy: 0.7606 - val_loss: 0.9780 - val_accuracy: 0.6756

# %% [markdown]
# ## Step 8: Visualizing the results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

fig = plt.figure(figsize=(12, 12))
fig.patch.set_facecolor('xkcd:mint green')

plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# **Todo: Write your findings after the model fit, see if there is an evidence of model overfit or underfit. Do you think there is some improvement now as compared to the previous model run?**
#
# **Comment:**
#
# *   With the help of augmented data, the problem of overfitting is mitigated.
# *   Training and validation accuracy of the above model are in the same range.
# *   The model is performing poorly both on training data and validation data- i.e. the model is underfitting now.
#
#
# **Todo: Find the distribution of classes in the training dataset.**
#
# **Context: Many times real life datasets can have class imbalance, one class can have proportionately higher number of samples compared to the others. Class imbalance can have a detrimental effect on the final model quality. Hence as a sanity check it becomes important to check what is the distribution of classes in the data.**

# %%
for i in class_names:
  sample_count = len(list(data_dir_train.glob(i + '/*.jpg')))
  print(str(i) + " class contains around: " + str(sample_count) + " sample count.")

# %%
from glob import glob
path_list = [ x for x in glob(os.path.join(data_dir_train, '*', '*.jpg')) ] 
lesion_list = [ os.path.basename(os.path.dirname(y)) for y in glob(os.path.join(data_dir_train, '*', '*.jpg')) ]
print(len(lesion_list))
# Out:
# 2239

# %%
df_dict_original = dict(zip(path_list, lesion_list))
print(list(df_dict_original.items())[:2])
# Out:
# [('/content/drive/MyDrive/Upgrad/ML2/CNN Project/Melanoma-Detection-Assignment/Train/actinic keratosis/ISIC_0028558.jpg', 'actinic keratosis'), ('/content/drive/MyDrive/Upgrad/ML2/CNN Project/Melanoma-Detection-Assignment/Train/actinic keratosis/ISIC_0026848.jpg', 'actinic keratosis')]

# %%
original_df = pd.DataFrame(list(df_dict_original.items()), columns=['Path','Label'])
original_df.head()
# Out:
#                                                 Path              Label
# 0  /content/drive/MyDrive/Upgrad/ML2/CNN Project/...  actinic keratosis
# 1  /content/drive/MyDrive/Upgrad/ML2/CNN Project/...  actinic keratosis
# 2  /content/drive/MyDrive/Upgrad/ML2/CNN Project/...  actinic keratosis
# 3  /content/drive/MyDrive/Upgrad/ML2/CNN Project/...  actinic keratosis
# 4  /content/drive/MyDrive/Upgrad/ML2/CNN Project/...  actinic keratosis

# %%
original_df[['Label']].value_counts()
# Out:
# Label
# pigmented benign keratosis    462
# melanoma                      438
# basal cell carcinoma          376
# nevus                         357
# squamous cell carcinoma       181
# vascular lesion               139
# actinic keratosis             114
# dermatofibroma                 95
# seborrheic keratosis           77
# dtype: int64

# %%
original_df[['Label']].value_counts(normalize=True)
# Out:
# Label
# pigmented benign keratosis    0.206342
# melanoma                      0.195623
# basal cell carcinoma          0.167932
# nevus                         0.159446
# squamous cell carcinoma       0.080840
# vascular lesion               0.062081
# actinic keratosis             0.050916
# dermatofibroma                0.042430
# seborrheic keratosis          0.034390
# dtype: float64

# %% [markdown]
# **Todo: Write your findings here:**
# - **Which class has the least number of samples?**
# - **Which classes dominate the data in terms proportionate number of samples?**
#
# **Comment:**
#
# -- `'seborrheic keratosis'` has the least number of samples
#
# -- the classes `'pigmented benign keratosis'` and 'melanoma' dominate the data with **20.6%** and **19.5%** samples respectively.
#
# **Todo: Rectify the class imbalance**
#
# **Context: You can use a python package known as Augmentor (https://augmentor.readthedocs.io/en/master/) to add more samples across all classes so that none of the classes have very few samples.**

# %%
# !pip install Augmentor
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting Augmentor
#   Downloading Augmentor-0.2.10-py2.py3-none-any.whl (38 kB)
# Requirement already satisfied: Pillow>=5.2.0 in /usr/local/lib/python3.8/dist-packages (from Augmentor) (7.1.2)
# Requirement already satisfied: future>=0.16.0 in /usr/local/lib/python3.8/dist-packages (from Augmentor) (0.16.0)
# Requirement already satisfied: tqdm>=4.9.0 in /usr/local/lib/python3.8/dist-packages (from Augmentor) (4.64.1)
# Requirement already satisfied: numpy>=1.11.0 in /usr/local/lib/python3.8/dist-packages (from Augmentor) (1.21.6)
# Installing collected packages: Augmentor
# Successfully installed Augmentor-0.2.10

# %%
path_to_training_dataset=str(data_dir_train) + '/'
import Augmentor
for i in class_names:
    p = Augmentor.Pipeline(path_to_training_dataset + i)
    p.rotate(probability=0.7, max_left_rotation=10, max_right_rotation=10)
    p.sample(500) ## We are adding 500 samples per class to make sure that none of the classes are sparse.
# Out:
# Initialised with 114 image(s) found.
# Output directory set to /content/drive/MyDrive/Upgrad/ML2/CNN Project/Melanoma-Detection-Assignment/Train/actinic keratosis/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7FAD1C805430>: 100%|██████████| 500/500 [00:39<00:00, 12.74 Samples/s]
# Initialised with 376 image(s) found.
# Output directory set to /content/drive/MyDrive/Upgrad/ML2/CNN Project/Melanoma-Detection-Assignment/Train/basal cell carcinoma/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7FAD1C7B9C70>: 100%|██████████| 500/500 [00:22<00:00, 22.32 Samples/s]
# Initialised with 95 image(s) found.
# Output directory set to /content/drive/MyDrive/Upgrad/ML2/CNN Project/Melanoma-Detection-Assignment/Train/dermatofibroma/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7FAD1C83E910>: 100%|██████████| 500/500 [00:23<00:00, 21.36 Samples/s]
# Initialised with 438 image(s) found.
# Output directory set to /content/drive/MyDrive/Upgrad/ML2/CNN Project/Melanoma-Detection-Assignment/Train/melanoma/output.
# Processing <PIL.Image.Image image mode=RGB size=1024x768 at 0x7FAD1C7FD220>: 100%|██████████| 500/500 [01:44<00:00,  4.77 Samples/s]
# Initialised with 357 image(s) found.
# Output directory set to /content/drive/MyDrive/Upgrad/ML2/CNN Project/Melanoma-Detection-Assignment/Train/nevus/output.
# Processing <PIL.Image.Image image mode=RGB size=962x641 at 0x7FAD1C784160>: 100%|██████████| 500/500 [01:33<00:00,  5.33 Samples/s]
# Initialised with 462 image(s) found.
# Output directory set to /content/drive/MyDrive/Upgrad/ML2/CNN Project/Melanoma-Detection-Assignment/Train/pigmented benign keratosis/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x450 at 0x7FAD1C79FB50>: 100%|██████████| 500/500 [00:23<00:00, 21.70 Samples/s]
# Initialised with 77 image(s) found.
# Output directory set to /content/drive/MyDrive/Upgrad/ML2/CNN Project/Melanoma-Detection-Assignment/Train/seborrheic keratosis/output.
# Processing <PIL.Image.Image image mode=RGB size=1024x768 at 0x7FAD2060ED90>: 100%|██████████| 500/500 [00:51<00:00,  9.68 Samples/s]
# Initialised with 181 image(s) found.
# Output directory set to /content/drive/MyDrive/Upgrad/ML2/CNN Project/Melanoma-Detection-Assignment/Train/squamous cell carcinoma/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7FAD2061CBE0>: 100%|██████████| 500/500 [00:22<00:00, 22.41 Samples/s]
# Initialised with 139 image(s) found.
# Output directory set to /content/drive/MyDrive/Upgrad/ML2/CNN Project/Melanoma-Detection-Assignment/Train/vascular lesion/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7FAD208E9A30>: 100%|██████████| 500/500 [00:22<00:00, 22.60 Samples/s]

# %%
image_count_train = len(list(data_dir_train.glob('*/output/*.jpg')))
print(image_count_train)
# Out:
# 4500

# %% [markdown]
# **Lets see the distribution of augmented data after adding new images to the original training data.**

# %%
path_list_new = [x for x in glob(os.path.join(data_dir_train, '*','output', '*.jpg'))]
path_list_new[:2]
# Out:
# ['/content/drive/MyDrive/Upgrad/ML2/CNN Project/Melanoma-Detection-Assignment/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0027950.jpg_d87a1a43-ef56-47a7-8533-57a5ef2fb4d1.jpg',
#  '/content/drive/MyDrive/Upgrad/ML2/CNN Project/Melanoma-Detection-Assignment/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0025957.jpg_ff0010f9-1be6-44f7-806f-985e2dfde9ee.jpg']

# %%
lesion_list_new = [os.path.basename(os.path.dirname(os.path.dirname(y))) for y in glob(os.path.join(data_dir_train, '*','output', '*.jpg'))]
lesion_list_new[:2]
# Out:
# ['actinic keratosis', 'actinic keratosis']

# %%
dataframe_dict_new = dict(zip(path_list_new, lesion_list_new))

# %%
df2 = pd.DataFrame(list(dataframe_dict_new.items()),columns = ['Path','Label'])
new_df = original_df.append(df2)
new_df.shape
# Out:
# (6739, 2)

# %%
new_df.head()
# Out:
#                                                 Path              Label
# 0  /content/drive/MyDrive/Upgrad/ML2/CNN Project/...  actinic keratosis
# 1  /content/drive/MyDrive/Upgrad/ML2/CNN Project/...  actinic keratosis
# 2  /content/drive/MyDrive/Upgrad/ML2/CNN Project/...  actinic keratosis
# 3  /content/drive/MyDrive/Upgrad/ML2/CNN Project/...  actinic keratosis
# 4  /content/drive/MyDrive/Upgrad/ML2/CNN Project/...  actinic keratosis

# %%
# Checking the class distribution after adding 500 samples per label
new_df['Label'].value_counts(normalize=True)
# Out:
# pigmented benign keratosis    0.142751
# melanoma                      0.139190
# basal cell carcinoma          0.129990
# nevus                         0.127170
# squamous cell carcinoma       0.101054
# vascular lesion               0.094821
# actinic keratosis             0.091111
# dermatofibroma                0.088292
# seborrheic keratosis          0.085621
# Name: Label, dtype: float64

# %%
new_df['Label'].value_counts()
# Out:
# pigmented benign keratosis    962
# melanoma                      938
# basal cell carcinoma          876
# nevus                         857
# squamous cell carcinoma       681
# vascular lesion               639
# actinic keratosis             614
# dermatofibroma                595
# seborrheic keratosis          577
# Name: Label, dtype: int64

# %% [markdown]
# ## Step 9: Training the Model

# %% [markdown]
# **Todo: Train the model on the data created using Augmentor**

# %%
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# **Todo: Create a training dataset**

# %%
# data_dir_train="path to directory with training data + data created using augmentor"
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  seed=123,
  validation_split = 0.2,
  subset = 'training',
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 6739 files belonging to 9 classes.
# Using 5392 files for training.

# %% [markdown]
# **Todo: Create a validation dataset**

# %%
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  seed=123,
  validation_split = 0.2,
  subset = 'validation',
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 6739 files belonging to 9 classes.
# Using 1347 files for validation.

# %% [markdown]
# **Todo: Create your model (make sure to include normalization)**

# %%
model = Sequential([
  data_augmentation,
  layers.experimental.preprocessing.Rescaling(1./255),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Dropout(0.2),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])

# %% [markdown]
# **Todo: Compile your model (Choose optimizer and loss function appropriately)**

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %% [markdown]
# **Todo: Train your model**

# %%
epochs = 30
## Your code goes here, use 50 epochs.
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/30
# 169/169 [==============================] - 229s 1s/step - loss: 1.7422 - accuracy: 0.3314 - val_loss: 1.4736 - val_accuracy: 0.4618
# Epoch 2/30
# 169/169 [==============================] - 220s 1s/step - loss: 1.4530 - accuracy: 0.4516 - val_loss: 1.3429 - val_accuracy: 0.4944
# Epoch 3/30
# 169/169 [==============================] - 225s 1s/step - loss: 1.3436 - accuracy: 0.4866 - val_loss: 1.2823 - val_accuracy: 0.4855
# Epoch 4/30
# 169/169 [==============================] - 222s 1s/step - loss: 1.2756 - accuracy: 0.5154 - val_loss: 1.2340 - val_accuracy: 0.5367
# Epoch 5/30
# 169/169 [==============================] - 220s 1s/step - loss: 1.1968 - accuracy: 0.5343 - val_loss: 1.2239 - val_accuracy: 0.5382
# Epoch 6/30
# 169/169 [==============================] - 225s 1s/step - loss: 1.1714 - accuracy: 0.5499 - val_loss: 1.3001 - val_accuracy: 0.5085
# Epoch 7/30
# 169/169 [==============================] - 220s 1s/step - loss: 1.1080 - accuracy: 0.5747 - val_loss: 1.2493 - val_accuracy: 0.5397
# Epoch 8/30
# 169/169 [==============================] - 220s 1s/step - loss: 1.0583 - accuracy: 0.5925 - val_loss: 1.1131 - val_accuracy: 0.5872
# Epoch 9/30
# 169/169 [==============================] - 222s 1s/step - loss: 0.9910 - accuracy: 0.6222 - val_loss: 1.0773 - val_accuracy: 0.6013
# Epoch 10/30
# 169/169 [==============================] - 220s 1s/step - loss: 0.9739 - accuracy: 0.6280 - val_loss: 1.0621 - val_accuracy: 0.6192
# Epoch 11/30
# 169/169 [==============================] - 220s 1s/step - loss: 0.9317 - accuracy: 0.6487 - val_loss: 0.9717 - val_accuracy: 0.6392
# Epoch 12/30
# 169/169 [==============================] - 221s 1s/step - loss: 0.8714 - accuracy: 0.6667 - val_loss: 1.0408 - val_accuracy: 0.6184
# Epoch 13/30
# 169/169 [==============================] - 221s 1s/step - loss: 0.8334 - accuracy: 0.6825 - val_loss: 0.8838 - val_accuracy: 0.6704
# Epoch 14/30
# 169/169 [==============================] - 220s 1s/step - loss: 0.7800 - accuracy: 0.7038 - val_loss: 0.8155 - val_accuracy: 0.7016
# Epoch 15/30
# 169/169 [==============================] - 220s 1s/step - loss: 0.7665 - accuracy: 0.7064 - val_loss: 0.8461 - val_accuracy: 0.6919
# Epoch 16/30
# 169/169 [==============================] - 221s 1s/step - loss: 0.7508 - accuracy: 0.7177 - val_loss: 0.8485 - val_accuracy: 0.6964
# Epoch 17/30
# 169/169 [==============================] - 220s 1s/step - loss: 0.7043 - accuracy: 0.7311 - val_loss: 0.7844 - val_accuracy: 0.7179
# Epoch 18/30
# 169/169 [==============================] - 223s 1s/step - loss: 0.6933 - accuracy: 0.7370 - val_loss: 0.7624 - val_accuracy: 0.7387
# Epoch 19/30
# 169/169 [==============================] - 221s 1s/step - loss: 0.6360 - accuracy: 0.7569 - val_loss: 0.7343 - val_accuracy: 0.7246
# Epoch 20/30
# 169/169 [==============================] - 220s 1s/step - loss: 0.6077 - accuracy: 0.7708 - val_loss: 0.7426 - val_accuracy: 0.7446
# Epoch 21/30
# 169/169 [==============================] - 220s 1s/step - loss: 0.6088 - accuracy: 0.7713 - val_loss: 0.7484 - val_accuracy: 0.7446
# Epoch 22/30
# 169/169 [==============================] - 220s 1s/step - loss: 0.5463 - accuracy: 0.7947 - val_loss: 0.8578 - val_accuracy: 0.6837
# Epoch 23/30
# 169/169 [==============================] - 220s 1s/step - loss: 0.5661 - accuracy: 0.7834 - val_loss: 0.6826 - val_accuracy: 0.7728
# Epoch 24/30
# 169/169 [==============================] - 220s 1s/step - loss: 0.5393 - accuracy: 0.7956 - val_loss: 0.6589 - val_accuracy: 0.7795
# Epoch 25/30
# 169/169 [==============================] - 222s 1s/step - loss: 0.5239 - accuracy: 0.7980 - val_loss: 0.6439 - val_accuracy: 0.7810
# Epoch 26/30
# 169/169 [==============================] - 220s 1s/step - loss: 0.5211 - accuracy: 0.8055 - val_loss: 0.6785 - val_accuracy: 0.7736
# Epoch 27/30
# 169/169 [==============================] - 221s 1s/step - loss: 0.4704 - accuracy: 0.8125 - val_loss: 0.6559 - val_accuracy: 0.7840
# Epoch 28/30
# 169/169 [==============================] - 222s 1s/step - loss: 0.5178 - accuracy: 0.8036 - val_loss: 0.6748 - val_accuracy: 0.7476
# Epoch 29/30
# 169/169 [==============================] - 220s 1s/step - loss: 0.4660 - accuracy: 0.8194 - val_loss: 0.6852 - val_accuracy: 0.8018
# Epoch 30/30
# 169/169 [==============================] - 220s 1s/step - loss: 0.4650 - accuracy: 0.8229 - val_loss: 0.5697 - val_accuracy: 0.8181

# %% [markdown]
# ## **Step 10:  Visualize the model results**

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accur|acy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# ## Final Results

# %% [markdown]
# **Todo: Analyze your results here. Did you get rid of underfitting/overfitting? Did class rebalance help?**

# %% [markdown]
# *   In the final model, there is no sign of underfitting/overfitting 🤟.
#
#   *   Train accuracy measured as <font color = green> **`77.6%`** </font>
#   *   Test accuracy measures as <font color = green> **`79.4%`** </font>
#
# *   **Class rebalanced** improved the model performance on both training and validation data.
#
# *   The low difference between the training accuracy and validation accuracy signifies that the final CNN model is able to generalize well.
#
# *   Inclusion of **batch normalization** is degrading the accuracy of the final model, hence it is not used.
